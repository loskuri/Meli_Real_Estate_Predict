# %%
import pandas as pd

# %%
v1 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_1.csv")
v2 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_2.csv")
v3 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_3.csv")
v4 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_4.csv")
v5 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_5.csv")
v6 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_6.csv")
v7 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_7.csv")
v8 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_8.csv")
v9 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_9.csv")
v10 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_10.csv")
v11 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_11.csv")
v12 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_12.csv")
v13 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_13.csv")
v14 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_14.csv")
# Out:
# C:\Users\lucki\AppData\Local\Temp\ipykernel_7416\2464246197.py:1: DtypeWarning: Columns (44,46,64,65,77,84,98,102,114,122,132,133,134,135,136,137,138,139,140,141,142,146,147,148,149,150,151,152,153,154,157,160,161,162,163,164,165,167,168,169,170,171,172,173,174,175,176,178,179,182,183,186,187,188,189,190,192,193,194,195,196,198,199,200,201,202,203,204,205,206,209,212,213,214,215,216,217,218,219,220,221,222,223,224,225,226,227,228,229,230,231,232,233,234,235,236,237,239,240,241,242,243,244,245,246,251,252,253,254,255,256,258,259,261,262,263,265,266,267,268,269,270,271,273,274,275,278,279,280,282,283,284,285,286,287,288,289,290,291,292,293,294,296,297,298,299,300,301,303,304,306,308,309) have mixed types. Specify dtype option on import or set low_memory=False.
#   v1 = pd.read_csv(r"D:\Tesis\Bases_datos_scrapeadas\db_1.csv")
# ...

# %%
result = pd.concat([v1, v2,v3,v4,v5,v6,v7,v8,v9,v10,v11,v12,v13,v14], ignore_index=True).drop_duplicates(subset= 'id')

# %%
result
# Out:
#          Unnamed: 0             id  \
# 0                 0  MLA1438813069
# 1                 1  MLA1438852077
# 2                 2  MLA1438738829
# 3                 3  MLA1442362231
# 4                 4  MLA1442988101
# ...             ...            ...
# 1108216      193988  MLA1460536907
# 1108299      194071  MLA1934636932
# 1108336      194108  MLA1951039308
# 1108359      194131  MLA1958655698
# 1108364      194136  MLA1952077224
#
#                                                      title      price  \
# 0                              Casa En Altura En El Chorro  1100000.0
# 1              20 Metros De La Playa En Relajada Localidad  1100000.0
# 2                                        Casa - Las Grutas  1100000.0
# 3               Impecable - Estilo Minimalista - Ref. 2504  1100000.0
# 4        Oportunidad!! Casa En Venta En Saint Thomas Oe...  1100000.0
# ...                                                    ...        ...
# ...

# %%
result_vta =  result[result["operation"] == 'Venta']

# %%
result_vta
# Out:
#          Unnamed: 0             id  \
# 0                 0  MLA1438813069
# 1                 1  MLA1438852077
# 2                 2  MLA1438738829
# 3                 3  MLA1442362231
# 4                 4  MLA1442988101
# ...             ...            ...
# 1106369      192141  MLA1938836260
# 1106411      192183  MLA1951362048
# 1106416      192188  MLA1951043654
# 1106523      192295  MLA1456386223
# 1107790      193562  MLA1830694400
#
#                                                      title      price  \
# 0                              Casa En Altura En El Chorro  1100000.0
# 1              20 Metros De La Playa En Relajada Localidad  1100000.0
# 2                                        Casa - Las Grutas  1100000.0
# 3               Impecable - Estilo Minimalista - Ref. 2504  1100000.0
# 4        Oportunidad!! Casa En Venta En Saint Thomas Oe...  1100000.0
# ...                                                    ...        ...
# ...

# %%
result_vta = result_vta[result_vta['location_state'].isin(["Capital Federal", "Bs.As. G.B.A. Norte", "Bs.As. G.B.A. Sur", "Bs.As. G.B.A. Oeste"])]

result_vta = result_vta[result_vta['property_type'].isin(["Departamento","Casa","Ph"])]

# %%
result_vta.to_csv(r'D:\Tesis\base_acumulada\data.csv')
